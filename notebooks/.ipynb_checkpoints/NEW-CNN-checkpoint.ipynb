# %%
import tensorflow as tf
from tensorflow import keras
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import misc
import cv2 as cv

# %%
path_classes = '../Img/GoodImg/Bmp/'
classes_names = sorted(os.listdir(path_classes))
dic_imgs ={}

for i, name_class in enumerate(classes_names):
    dic_imgs[classes_names[i]]=np.array(os.listdir(path_classes + classes_names[i]))
    print "class: ", name_class, " total samples: ", len(dic_imgs[classes_names[i]])
# Out:
# class:  Sample001  total samples:  155
# class:  Sample002  total samples:  146
# class:  Sample003  total samples:  118
# class:  Sample004  total samples:  80
# class:  Sample005  total samples:  73
# class:  Sample006  total samples:  81
# class:  Sample007  total samples:  84
# class:  Sample008  total samples:  61
# class:  Sample009  total samples:  42
# class:  Sample010  total samples:  71
# class:  Sample011  total samples:  918
# class:  Sample012  total samples:  179
# class:  Sample013  total samples:  339
# class:  Sample014  total samples:  328
# class:  Sample015  total samples:  713
# class:  Sample016  total samples:  136
# class:  Sample017  total samples:  220
# class:  Sample018  total samples:  303
# class:  Sample019  total samples:  540
# class:  Sample020  total samples:  102
# class:  Sample021  total samples:  134
# class:  Sample022  total samples:  334
# class:  Sample023  total samples:  253
# class:  Sample024  total samples:  556
# class:  Sample025  total samples:  582
# class:  Sample026  total samples:  261
# class:  Sample027  total samples:  41
# class:  Sample028  total samples:  616
# class:  Sample029  total samples:  540
# class:  Sample030  total samples:  513
# class:  Sample031  total samples:  166
# class:  Sample032  total samples:  128
# class:  Sample033  total samples:  112
# class:  Sample034  total samples:  86
# class:  Sample035  total samples:  107
# class:  Sample036  total samples:  68

# %%
X=[];
Y=[];
for i in range(len(classes_names)):
    for j in range(len(dic_imgs[classes_names[i]])):

        path_image = path_classes+classes_names[i]+'/'+dic_imgs[classes_names[i]][j];
        img=cv.imread(path_image);
        img=cv.cvtColor(img,cv.COLOR_BGR2RGB);
        img=cv.resize(img,(64,64));
        X.append(img)
        Y.append(i)

X=np.asanyarray(X)
Y=np.asanyarray(Y)

# %%
from sklearn.model_selection import train_test_split
test_size = 0.3
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=test_size)
print X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# (6430, 64, 64, 3) (2756, 64, 64, 3) (6430,) (2756,)

# %%
X_train = X_train.reshape([-1, 64, 64, 3])
X_test = X_test.reshape([-1, 64, 64, 3])
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train /= 255
X_test /= 255

# %%
model=  keras.models.Sequential()
model.add(keras.layers.Conv2D(60, (5, 5), input_shape=(64, 64,3), activation='relu'))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(keras.layers.Conv2D(30, (3, 3), activation='relu'))
model.add(keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128, activation='relu'))
model.add(keras.layers.Dense(50, activation='relu'))
model.add(keras.layers.Dense(36, activation='softmax'))

model.summary();
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 60, 60, 60)        4560
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 30, 30, 60)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 28, 28, 30)        16230
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 14, 14, 30)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 14, 14, 30)        0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 5880)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 128)               752768
# _________________________________________________________________
# dense_28 (Dense)             (None, 50)                6450
# _________________________________________________________________
# dense_29 (Dense)             (None, 36)                1836
# =================================================================
# Total params: 781,844
# Trainable params: 781,844
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = keras.optimizers.SGD(lr=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history = model.fit(X_train, Y_train, epochs=150, batch_size=64,
                    validation_data=(X_test, Y_test))
# Out:
# Train on 6430 samples, validate on 2756 samples
# Epoch 1/150
# 6430/6430 [==============================] - 39s 6ms/sample - loss: 3.4735 - acc: 0.0858 - val_loss: 3.3643 - val_acc: 0.0929
# Epoch 2/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 3.3333 - acc: 0.1017 - val_loss: 3.2860 - val_acc: 0.0882
# Epoch 3/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss:
150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0190 - acc: 0.9961 - val_loss: 1.7293 - val_acc: 0.8041
# Epoch 139/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0145 - acc: 0.9974 - val_loss: 1.7009 - val_acc: 0.8055
# Epoch 140/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0177 - acc: 0.9956 - val_loss: 1.7654 - val_acc: 0.8052
# Epoch 141/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0181 - acc: 0.9953 - val_loss: 1.7034 - val_acc: 0.8070
# Epoch 142/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0183 - acc: 0.9963 - val_loss: 1.7644 - val_acc: 0.8008
# Epoch 143/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0175 - acc: 0.9963 - val_loss: 1.6992 - val_acc: 0.8077
# Epoch 144/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0223 - acc: 0.9953 - val_loss: 1.7212 - val_acc: 0.8008
# Epoch 145/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0227 - acc: 0.9944 - val_loss: 1.6924 - val_acc: 0.8044
# Epoch 146/150
# 6430/6430 [==============================] - 38s 6ms/sample - loss: 0.0209 - acc: 0.9952 - val_loss: 1.7705 - val_acc: 0.8110
# Epoch 147/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0151 - acc: 0.9974 - val_loss: 1.8671 - val_acc: 0.8022
# Epoch 148/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0195 - acc: 0.9960 - val_loss: 1.7581 - val_acc: 0.7979
# Epoch 149/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0229 - acc: 0.9956 - val_loss: 1.8229 - val_acc: 0.7990
# Epoch 150/150
# 6430/6430 [==============================] - 37s 6ms/sample - loss: 0.0234 - acc: 0.9946 - val_loss: 1.8175 - val_acc: 0.8022

# %%
plt.plot(history.history['acc'], label='Train Accuracy')
plt.plot(history.history['val_acc'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
def indentificar(features):
    if np.argmax(features)==0:
        return 0
    if np.argmax(features)==1:
        return 1
    if np.argmax(features)==2:
        return 2
    if np.argmax(features)==3:
        return 3
    if np.argmax(features)==4:
        return 4
    if np.argmax(features)==5:
        return 5
    if np.argmax(features)==6:
        return 6
    if np.argmax(features)==7:
        return 7
    if np.argmax(features)==8:
        return 8
    if np.argmax(features)==9:
        return 9
    if np.argmax(features)==10:
        return 'A'
    if np.argmax(features)==11:
        return 'B'
    if np.argmax(features)==12:
        return 'C'
    if np.argmax(features)==13:
        return 'D'
    if np.argmax(features)==14:
        return 'E'
    if np.argmax(features)==15:
        return 'F'
    if np.argmax(features)==16:
        return 'G'
    if np.argmax(features)==17:
        return 'H'
    if np.argmax(features)==18:
        return 'I'
    if np.argmax(features)==19:
        return 'J'
    if np.argmax(features)==20:
        return 'K'
    if np.argmax(features)==21:
        return 'L'
    if np.argmax(features)==22:
        return 'M'
    if np.argmax(features)==23:
        return 'N'
    if np.argmax(features)==24:
        return 'O'
    if np.argmax(features)==25:
        return 'P'
    if np.argmax(features)==26:
        return 'Q'
    if np.argmax(features)==27:
        return 'R'
    if np.argmax(features)==28:
        return 'S'
    if np.argmax(features)==29:
        return 'T'
    if np.argmax(features)==30:
        return 'U'
    if np.argmax(features)==31:
        return 'V'
    if np.argmax(features)==32:
        return 'W'
    if np.argmax(features)==33:
        return 'X'
    if np.argmax(features)==34:
        return 'Y'
    if np.argmax(features)==35:
        return 'Z'

# %%
ima=cv.imread('../Letras/caracter_6_0.jpg')
ima=cv.cvtColor(ima,cv.COLOR_BGR2RGB)
plt.imshow(ima)
ima=cv.resize(ima,(64,64))
ima = ima.reshape([-1, 64, 64, 3])
ima = ima.astype('float32')
ima /= 255

features=model.predict(ima)
print indentificar(features)
# Out:
# 4

# %%
model.save('my_new_model_64.h5')
